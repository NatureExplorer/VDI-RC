# %% [markdown]
# # TUGAS 3 VDI RC
#
# ## Muhammad Farhan 121450044

# %% [markdown]
# 1. Tentukan data yang akan anda gunakan dalam visualisasi

# %%
import pandas as pdi #Mengimport pandas guna melakukan manipulasi data

# %%
diabetes1 = pdi.read_csv('/content/diabetes_RS1.csv') #Memasukkan variabel diabetes1 dari file lokal dengan menggunakan bantuan library pandas
diabetes2 = pdi.read_csv('/content/diabetes_RS2.csv') #Memasukkan variabel diabetes2 dari file lokal dengan menggunakan bantuan library pandas

# %%
#Mengubah nama pada dataset diabetes1 kolom Age menjadi AGE untuk melakukan integrasi pada kedua data
diabetes1.rename(columns={'Age':'AGE'},inplace=True) #Merubah nama kolom Age pada data diabetes1 sebagai AGE untuk menyamakan pada data diabetes2
diabetes1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  AGE  Outcome
# 0                       0.627   50        1
# ...

# %%
diabetes = pdi.merge(diabetes1,diabetes2,on='AGE') #Melakukan penggabungan data pada diabetes1 dan diabetes2 berdasarkan kolom AGE
diabetes #Dapat terlihat baris bertambah menjadi 6621 baris dan 22 kolom
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI_x  \
# 0               6      148             72             35        0   33.6
# 1               6      148             72             35        0   33.6
# 2               6      148             72             35        0   33.6
# 3               6      148             72             35        0   33.6
# 4               6      148             72             35        0   33.6
# ...           ...      ...            ...            ...      ...    ...
# 6616            8       91             82              0        0   35.6
# 6617            8       91             82              0        0   35.6
# 6618            8       91             82              0        0   35.6
# 6619            8       91             82              0        0   35.6
# 6620            8       91             82              0        0   35.6
#
#       DiabetesPedigreeFunction  AGE  Outcome   ID  ...  Urea    Cr  HbA1c  \
# ...

# %%
diabetes.to_csv('data_integration.csv') #Menjadikan data pada diabetes menjadi csv dengan nama data_integration.csv

# %% [markdown]
# 2. Berdasarkan data yang anda pilih tentukan tujuan, user, fungsi dan tone (jika ada) yang sesuai dengan visualisasi yang akan anda buat

# %%
pca2 = PCA(n_components = 2) #Mengassign pca 2 yang akan melakukan perintah PCA dengan jumlah n_components sebanyak 2
digits_pca2 = pca2.fit_transform(digitsX) #Menamakan digits_pca2 yang merupakan perintah fit_transform pca2 pada digitsX
# Out:
# time: 34.1 ms (started: 2023-09-29 01:51:03 +00:00)

# %%
print(pca2.explained_variance_ratio_) #Mencetak  nilai rasio variansi dari pca2
print(pca2.singular_values_) #Mencetak nilai singular dari fungsi pca2
# Out:
# [0.14890594 0.13618771]
# [567.0065665  542.25185421]
# time: 2.63 ms (started: 2023-09-29 01:51:05 +00:00)

# %%
digits_pca2 = pdi.DataFrame(data = digits_pca2, columns = ['comp1', 'comp2']) #Mengassign digits_pca2 yang merupakan dataframe dari digits_pca2 dengan kolom comp1 dan comp2
digits_pca2['label'] = digitsY #Mengassign kolom label pada data digits_pca2 sebagai digitsY
# Out:
# time: 2.08 ms (started: 2023-09-29 01:51:16 +00:00)

# %%
# Set style of scatterplot
sns.set_context("notebook", font_scale=1.1)
sns.set_style("ticks")

# Create scatterplot of dataframe
sns.lmplot(x='comp1',
           y='comp2',
           data=digits_pca2,
           fit_reg=False,
           legend=True,
           height=9,
           hue = 'label',
           scatter_kws={"s":200, "alpha":0.3})

plt.title('PCA Results: Digits', weight='bold').set_fontsize('14')
plt.xlabel('Principal Comp 1', weight='bold').set_fontsize('10')
plt.ylabel('Principal Comp 2', weight='bold').set_fontsize('10')
# Out:
# time: 1.08 s (started: 2023-09-29 01:51:19 +00:00)

# %% [markdown]
# Tujuan = ingin menampilkan scatterplot 10 label hasil PCA yang dibuat dengan beragam warna
#
# User = Ahli Analisis Data

# %% [markdown]
# 3. Buatlah visualisasi dengan mengunakan library python seperti matplotlib, seaborn atau tools lain

# %%
import seaborn as sns
import matplotlib.pyplot as plt
